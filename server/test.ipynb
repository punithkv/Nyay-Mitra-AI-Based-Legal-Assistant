# %%
import os
import random
import time
import base64
from main import NyayMitra
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings
from langchain_chroma import Chroma
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from dotenv import load_dotenv
from langchain.schema import HumanMessage
import uuid

# %%
load_dotenv(override=True)

#random thread id for session
id = uuid.uuid4()
thread_id = str(id)

# Load API key
gemini_api_key = os.getenv('GOOGLE_API_KEY')
#Defining the Language Model
llm = ChatGoogleGenerativeAI(model='gemini-2.0-flash', google_api_key=gemini_api_key, temperature=0.9, convert_system_message_to_human=True)

#Defining the Embeddings
embeddings = GoogleGenerativeAIEmbeddings(model='models/embedding-001', google_api_key=gemini_api_key)

#Defining the vector store
vector_store = Chroma(persist_directory="chroma", embedding_function=embeddings)

#Creating the instance of the class NyayMitra
law = NyayMitra(llm, embeddings, vector_store)
# Out:
# 2026-01-04 10:22:33,080 INFO Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2026-01-04 10:22:34,143 ERROR Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# 2026-01-04 10:22:34,219 ERROR Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# 2026-01-04 10:22:34,222 INFO NyayMitra initialized successfully

# %%
query="WHat is rule of Law?"

# %%
chat_history=None

# %%
result = law.conversational(query, thread_id)
# Out:
# 2026-01-04 10:23:18,652 INFO Cache miss for key: llm_cache:568c91a9640cce0c4880cf3a565d3ae3f7d3e2dd17730af1c209c217a5a64afa. Generating new answer.
# 2026-01-04 10:23:18,676 INFO Created new chat history for session_id: bdf42d33-0830-47a4-a043-b56b0024b36c
# 2026-01-04 10:23:26,818 ERROR Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# 2026-01-04 10:23:26,837 WARNING No relevant docs were retrieved using the relevance score threshold 0.3
# /home/owais/projects/Major Project/server/.venv/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:357: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")

# %%
print(result)
# Out:
# ('The query "What is the rule of law?" is a general legal question that does not directly relate to any specific legal context or information provided. Therefore, I cannot provide a specific legal answer based on the available context.', [HumanMessage(content='WHat is rule of Law?', additional_kwargs={}, response_metadata={}), AIMessage(content='The query "What is the rule of law?" is a general legal question that does not directly relate to any specific legal context or information provided. Therefore, I cannot provide a specific legal answer based on the available context.', additional_kwargs={}, response_metadata={})])
